# %% [markdown]
# <a href="https://colab.research.google.com/github/amrutha-m-sajeev/Machine-Learning-Using-Linear-Regression/blob/main/cgpa_package.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/content/placement.csv')
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
df.tail()
# Out:
#      cgpa  package
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33

# %%
df.isna().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   cgpa     200 non-null    float64
#  1   package  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.2 KB

# %%
df.columns
# Out:
# Index(['cgpa', 'package'], dtype='object')

# %%
df.describe()
# Out:
#              cgpa     package
# count  200.000000  200.000000
# mean     6.990500    2.996050
# std      1.069409    0.691644
# min      4.260000    1.370000
# 25%      6.190000    2.487500
# 50%      6.965000    2.995000
# 75%      7.737500    3.492500
# max      9.580000    4.620000

# %%
x=df.iloc[:,:-1]
x
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]

# %%
y=df.iloc[:,-1]
y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
x.ndim
# Out:
# 2

# %%
y.ndim
# Out:
# 1

# %%
plt.scatter(x,y,color='g')
plt.xlabel('cgpa')
plt.ylabel('package')
plt.title('CGPA-PACKAGE',color='r')
# Out:
# Text(0.5, 1.0, 'CGPA-PACKAGE')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)
x_train
# Out:
#      cgpa
# 169  9.31
# 97   5.98
# 31   8.10
# 12   8.94
# 35   6.87
# ..    ...
# 106  6.13
# 14   7.73
# 92   7.90
# 179  7.14
# 102  5.13
#
# [140 rows x 1 columns]

# %%
x_test
# Out:
#      cgpa
# 95   6.63
# 15   7.25
# 30   7.36
# 158  5.95
# 128  7.93
# 115  8.35
# 69   7.30
# 170  6.22
# 174  7.32
# 45   7.87
# 66   5.11
# 182  5.88
# 165  8.21
# 78   6.59
# 186  7.84
# 177  7.09
# 56   5.84
# 152  7.37
# 82   5.58
# 68   7.56
# 124  6.06
# 16   6.84
# 148  7.57
# 93   6.79
# 65   7.60
# 60   5.61
# 84   4.26
# 67   6.51
# 125  7.33
# 132  5.84
# 9    8.31
# 18   6.94
# 55   8.20
# 75   6.97
# 150  6.30
# 104  7.62
# 135  6.10
# 137  7.14
# 164  9.06
# 76   6.94
# 79   7.18
# 197  7.21
# 38   8.62
# 24   6.53
# 122  5.12
# 195  6.93
# 29   7.15
# 19   7.48
# 143  4.85
# 86   7.61
# 114  5.84
# 173  6.75
# 5    7.89
# 126  5.91
# 117  7.12
# 73   8.44
# 140  7.91
# 98   7.69
# 172  6.93
# 96   7.11

# %%
y_train
# Out:
# 169    4.37
# 97     2.84
# 31     3.89
# 12     3.65
# 35     2.87
#        ...
# 106    2.19
# 14     3.42
# 92     4.00
# 179    3.03
# 102    1.37
# Name: package, Length: 140, dtype: float64

# %%
y_test
# Out:
# 95     2.79
# 15     3.23
# 30     3.26
# 158    3.04
# 128    3.34
# 115    4.21
# 69     2.94
# 170    2.87
# 174    2.99
# 45     3.58
# 66     1.63
# 182    2.08
# 165    4.08
# 78     2.21
# 186    3.47
# 177    3.64
# 56     2.74
# 152    3.08
# 82     2.17
# 68     2.99
# 124    2.31
# 16     2.35
# 148    3.40
# 93     3.08
# 65     3.81
# 60     2.19
# 84     1.53
# 67     2.89
# 125    3.16
# 132    2.48
# 9      3.51
# 18     2.98
# 55     3.39
# 75     3.28
# 150    2.73
# 104    3.74
# 135    2.60
# 137    3.13
# 164    3.82
# 76     3.15
# 79     3.00
# 197    3.24
# 38     4.36
# 24     2.71
# 122    2.01
# 195    2.46
# 29     3.49
# 19     2.83
# 143    1.54
# 86     2.77
# 114    1.87
# 173    2.56
# 5      2.99
# 126    2.60
# 117    2.99
# 73     4.03
# 140    3.15
# 98     3.83
# 172    2.51
# 96     2.61
# Name: package, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([2.79941586, 3.15292804, 3.21564795, 2.41169282, 3.54065108,
#        3.78012708, 3.18143709, 2.56564168, 3.19284071, 3.50644023,
#        1.93274083, 2.37178016, 3.70030175, 2.77660862, 3.4893348 ,
#        3.06169909, 2.34897292, 3.22134976, 2.20072587, 3.32968414,
#        2.47441273, 2.91915386, 3.33538594, 2.89064481, 3.35249137,
#        2.2178313 , 1.44808703, 2.73099415, 3.19854252, 2.34897292,
#        3.75731984, 2.97617195, 3.69459994, 2.99327738, 2.61125615,
#        3.36389499, 2.49721996, 3.09020814, 4.18495554, 2.97617195,
#        3.11301538, 3.13012081, 3.93407593, 2.74239777, 1.93844264,
#        2.97047014, 3.09590995, 3.28406966, 1.78449379, 3.35819318,
#        2.34897292, 2.86783757, 3.51784385, 2.38888558, 3.07880452,
#        3.83144336, 3.52924746, 3.40380766, 2.97047014, 3.07310271])

# %%
print(model.predict([[1.45]]))
# Out:
# [-0.15412141]
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(x_train,y_train,color='r')
plt.plot(x_test,y_pred)

# %%
print("slope is:",model.coef_)
# Out:
# slope is: [0.57018094]

# %%
print("intercept:",model.intercept_)
# Out:
# intercept: -0.980883767663578

# %%
df1=pd.DataFrame({'actual value':y_test,'predict':y_pred})
df1
# Out:
#      actual value   predict
# 95           2.79  2.799416
# 15           3.23  3.152928
# 30           3.26  3.215648
# 158          3.04  2.411693
# 128          3.34  3.540651
# 115          4.21  3.780127
# 69           2.94  3.181437
# 170          2.87  2.565642
# 174          2.99  3.192841
# 45           3.58  3.506440
# 66           1.63  1.932741
# 182          2.08  2.371780
# 165          4.08  3.700302
# 78           2.21  2.776609
# 186          3.47  3.489335
# 177          3.64  3.061699
# 56           2.74  2.348973
# 152          3.08  3.221350
# 82           2.17  2.200726
# 68           2.99  3.329684
# 124          2.31  2.474413
# 16           2.35  2.919154
# 148          3.40  3.335386
# 93           3.08  2.890645
# 65           3.81  3.352491
# 60           2.19  2.217831
# 84           1.53  1.448087
# 67           2.89  2.730994
# 125          3.16  3.198543
# 132          2.48  2.348973
# 9            3.51  3.757320
# 18           2.98  2.976172
# ...

# %%
from sklearn.metrics import mean_absolute_error
print("Mean absoulte error is",mean_absolute_error(y_test,y_pred))
# Out:
# Mean absoulte error is 0.2606898249919377

# %%
from sklearn.metrics import mean_absolute_percentage_error
print("Mean absoulte percentage error is",mean_absolute_percentage_error(y_test,y_pred))
# Out:
# Mean absoulte percentage error is 0.09188769247425728

# %%
from sklearn.metrics import mean_squared_error
print("Mean squred error is",mean_squared_error(y_test,y_pred))
# Out:
# Mean squred error is 0.09995369482155111

# %%
root=mean_squared_error(y_test,y_pred)
squ=np.sqrt(root)
print(squ)
# Out:
# 0.3161545426236212

# %%
from sklearn.metrics import r2_score
print("r2 score:",r2_score(y_test,y_pred))
# Out:
# r2 score: 0.7525945592908275
