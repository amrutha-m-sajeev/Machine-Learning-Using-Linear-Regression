# %% [markdown]
# <a href="https://colab.research.google.com/github/amrutha-m-sajeev/Machine-Learning-Using-Linear-Regression/blob/main/startup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('/content/50_Startups.csv')
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df.tail()
# Out:
#     R&D Spend  Administration  Marketing Spend       State    Profit
# 45    1000.23       124153.04          1903.93    New York  64926.08
# 46    1315.46       115816.21        297114.46     Florida  49490.75
# 47       0.00       135426.92             0.00  California  42559.73
# 48     542.05        51743.15             0.00    New York  35673.41
# 49       0.00       116983.80         45173.06  California  14681.40

# %%
df.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State', 'Profit'], dtype='object')

# %%
df.isna().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['State']=le.fit_transform(df['State'])

# %%
x=df.iloc[:,:-1]
x
# Out:
#     R&D Spend  Administration  Marketing Spend  State
# 0   165349.20       136897.80        471784.10      2
# 1   162597.70       151377.59        443898.53      0
# 2   153441.51       101145.55        407934.54      1
# 3   144372.41       118671.85        383199.62      2
# 4   142107.34        91391.77        366168.42      1
# 5   131876.90        99814.71        362861.36      2
# 6   134615.46       147198.87        127716.82      0
# 7   130298.13       145530.06        323876.68      1
# 8   120542.52       148718.95        311613.29      2
# 9   123334.88       108679.17        304981.62      0
# 10  101913.08       110594.11        229160.95      1
# 11  100671.96        91790.61        249744.55      0
# 12   93863.75       127320.38        249839.44      1
# 13   91992.39       135495.07        252664.93      0
# 14  119943.24       156547.42        256512.92      1
# 15  114523.61       122616.84        261776.23      2
# ...

# %%
y=df.iloc[:,-1]
y
# Out:
# 0     192261.83
# 1     191792.06
# 2     191050.39
# 3     182901.99
# 4     166187.94
# 5     156991.12
# 6     156122.51
# 7     155752.60
# 8     152211.77
# 9     149759.96
# 10    146121.95
# 11    144259.40
# 12    141585.52
# 13    134307.35
# 14    132602.65
# 15    129917.04
# 16    126992.93
# 17    125370.37
# 18    124266.90
# 19    122776.86
# 20    118474.03
# 21    111313.02
# 22    110352.25
# 23    108733.99
# 24    108552.04
# 25    107404.34
# 26    105733.54
# 27    105008.31
# 28    103282.38
# 29    101004.64
# 30     99937.59
# 31     97483.56
# 32     97427.84
# 33     96778.92
# 34     96712.80
# 35     96479.51
# 36     90708.19
# 37     89949.14
# 38     81229.06
# 39     81005.76
# 40     78239.91
# 41     77798.83
# 42     71498.49
# 43     69758.98
# 44     65200.33
# 45     64926.08
# 46     49490.75
# 47     42559.73
# 48     35673.41
# 49     14681.40
# Name: Profit, dtype: float64

# %%
sns.regplot(x=df['R&D Spend'],y=y,scatter_kws={"color":"m"},line_kws={"color":"r"})
# Out:
# <Axes: xlabel='R&D Spend', ylabel='Profit'>

# %%
sns.regplot(x=df['Administration'],y=y,scatter_kws={"color":"c"},line_kws={"color":"r"})
# Out:
# <Axes: xlabel='Administration', ylabel='Profit'>

# %%
sns.regplot(x=df['Marketing Spend'],y=y,scatter_kws={"color":"black"},line_kws={"color":"r"})
# Out:
# <Axes: xlabel='Marketing Spend', ylabel='Profit'>

# %%
sns.regplot(x=df['State'],y=y,scatter_kws={"color":"c"},line_kws={"color":"r"})
# Out:
# <Axes: xlabel='State', ylabel='Profit'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)
x_train
# Out:
#     R&D Spend  Administration  Marketing Spend  State
# 6   134615.46       147198.87        127716.82      0
# 41   27892.92        84710.77        164470.71      1
# 46    1315.46       115816.21        297114.46      1
# 47       0.00       135426.92             0.00      0
# 15  114523.61       122616.84        261776.23      2
# 9   123334.88       108679.17        304981.62      0
# 16   78013.11       121597.55        264346.06      0
# 24   77044.01        99281.34        140574.81      2
# 34   46426.07       157693.92        210797.67      0
# 31   61136.38       152701.92         88218.23      2
# 0   165349.20       136897.80        471784.10      2
# 44   22177.74       154806.14         28334.72      0
# 27   72107.60       127864.55        353183.81      2
# 33   55493.95       103057.49        214634.81      1
# 5   131876.90        99814.71        362861.36      2
# 29   65605.48       153032.06        107138.38      2
# ...

# %%
x_test
# Out:
#     R&D Spend  Administration  Marketing Spend  State
# 13   91992.39       135495.07        252664.93      0
# 39   38558.51        82982.09        174999.30      0
# 30   61994.48       115641.28         91131.24      1
# 45    1000.23       124153.04          1903.93      2
# 17   94657.16       145077.58        282574.31      2
# 48     542.05        51743.15             0.00      2
# 26   75328.87       144135.98        134050.07      1
# 25   64664.71       139553.16        137962.62      0
# 32   63408.86       129219.61         46085.25      0
# 19   86419.70       153514.11             0.00      2
# 12   93863.75       127320.38        249839.44      1
# 4   142107.34        91391.77        366168.42      1
# 37   44069.95        51283.14        197029.42      0
# 8   120542.52       148718.95        311613.29      2
# 3   144372.41       118671.85        383199.62      2

# %%
y_train
# Out:
# 6     156122.51
# 41     77798.83
# 46     49490.75
# 47     42559.73
# 15    129917.04
# 9     149759.96
# 16    126992.93
# 24    108552.04
# 34     96712.80
# 31     97483.56
# 0     192261.83
# 44     65200.33
# 27    105008.31
# 33     96778.92
# 5     156991.12
# 29    101004.64
# 11    144259.40
# 36     90708.19
# 1     191792.06
# 21    111313.02
# 2     191050.39
# 43     69758.98
# 35     96479.51
# 23    108733.99
# 40     78239.91
# 10    146121.95
# 22    110352.25
# 18    124266.90
# 49     14681.40
# 20    118474.03
# 7     155752.60
# 42     71498.49
# 14    132602.65
# 28    103282.38
# 38     81229.06
# Name: Profit, dtype: float64

# %%
y_test
# Out:
# 13    134307.35
# 39     81005.76
# 30     99937.59
# 45     64926.08
# 17    125370.37
# 48     35673.41
# 26    105733.54
# 25    107404.34
# 32     97427.84
# 19    122776.86
# 12    141585.52
# 4     166187.94
# 37     89949.14
# 8     152211.77
# 3     182901.99
# Name: Profit, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([126568.76941326,  86103.32065505,  98856.91970393,  45879.38189926,
#        127503.1145004 ,  51963.50258406, 108272.77409836, 100861.53154191,
#         98046.22765053, 111719.28851222, 128104.23859919, 173506.28248936,
#         94030.7427099 , 148809.64824417, 172762.2638076 ])

# %%
print("slope is:",model.coef_)
# Out:
# slope is: [ 8.02342671e-01 -8.98833727e-02  2.97842241e-02 -6.16616475e+02]

# %%
print("intercepet is:",model.intercept_)
# Out:
# intercepet is: 57412.674523011585

# %%
df1=pd.DataFrame({'actual value':y_test,'predict':y_pred})
df1
# Out:
#     actual value        predict
# 13     134307.35  126568.769413
# 39      81005.76   86103.320655
# 30      99937.59   98856.919704
# 45      64926.08   45879.381899
# 17     125370.37  127503.114500
# 48      35673.41   51963.502584
# 26     105733.54  108272.774098
# 25     107404.34  100861.531542
# 32      97427.84   98046.227651
# 19     122776.86  111719.288512
# 12     141585.52  128104.238599
# 4      166187.94  173506.282489
# 37      89949.14   94030.742710
# 8      152211.77  148809.648244
# 3      182901.99  172762.263808

# %%
from sklearn.metrics import mean_absolute_error
print("Mean absoulte error is:",mean_absolute_error(y_test,y_pred))
# Out:
# Mean absoulte error is: 7371.161531074822

# %%
from sklearn.metrics import mean_absolute_percentage_error
print("Mean absoulte percentage error is:",mean_absolute_percentage_error(y_test,y_pred))
# Out:
# Mean absoulte percentage error is: 0.08947588976768113

# %%
from sklearn.metrics import mean_squared_error
print("Mean squerd error is:",mean_squared_error(y_test,y_pred))
# Out:
# Mean squerd error is: 83866027.64389345

# %%
root=mean_squared_error(y_test,y_pred)
squ=np.sqrt(root)
print(squ)
# Out:
# 9157.839682146301

# %%
from sklearn.metrics import r2_score
print("r2 score:",r2_score(y_test,y_pred))
# Out:
# r2 score: 0.9403937677548101
